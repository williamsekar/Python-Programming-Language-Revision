# %%
# PRINT THE VALUES

# %%
print("Welcome")
# Out:
# Welcome

# %%
# PRINT THE MULTIPLE VALUES

# %%
print("CR",42)
# Out:
# CR 42

# %%
# GET THE VALUE FORM THE USER

# %%
username = input("Enter the your username:")
print(username)
# Out:
# Enter the your username: William Sekar
# William Sekar

# %%
# USING A "sep" KEYWORD TO INSERT THE STRING'S, NUMBERS, SYMBOLS, ESCAPES CHARACTERS IN BETWEEN VALUES

# %%
print("File", "New", "Filename", sep= " -> ")
# Out:
# File -> New -> Filename

# %%
# USING A "end" KEYWORD TO INSERT THE STRING'S, NUMBERS, SYMBOLS, ESCAPES CHARACTERS IN END OF THE LINE

# %%
print("This is my paragraph", end="\t")
print("This is my paragraph")
# Out:
# This is my paragraph	This is my paragraph

# %%
# READING MULTIPLE VALUES IN ONE LINE

# %%
door_no, apartment_name, = input("Enter the door no and apartment name: ").split()
print(door_no, apartment_name)
# Out:
# Enter the door no and apartment name:  311 Kamarajar
# 311 Kamarajar

# %%
# REAFING MULTIPLE INTEGERS

# %%
a,b = input("Enter the a,b values:").split()
print(a,b)
# Out:
# Enter the a,b values: 10 20
# 10 20
