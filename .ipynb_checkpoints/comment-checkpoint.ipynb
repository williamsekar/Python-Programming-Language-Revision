# %%
SINGLE - LINE COMMENT (#)

# %%
# This a comment

# %%
INLINE COMMENT

# %%
age = 27 # current age

# %%
MULTI LINE COMMENTS

# %%
# First line
# Second line

# %%
TRIPLE QUOTES ( ''' or """ )

# %%
""" 
This is a multi-line string
It's often used as a  docstring
"""

# %%
DOCSTRINGS

# %%
def greet():
    ''' PRINT A WELCOME MESSSAGE '''
    print("Welcome")
greet()
# Out:
# Welcome

# %%
KEYBOARD SHORTCUTS

# %%
vscode -> Ctrl + /
pycharm -> Ctrl + /
