# %%
# CREATE A VARIABLE AND PRINT

# %%
name = "William"
print(name)
# Out:
# William

# %%
# MULTIPLE VARIABLES

# %%
age = 27
city = "Nellai"
print(name)
print(age)
print(city)
# Out:
# William
# 27
# Nellai

# %%
# CHANGING THE VARIABLES VALUES

# %%
age = 28
city = "Palayamkottai"
print(age)
print(city)
# Out:
# 28
# Palayamkottai

# %%
# VARIABLE TYPES

# %%
## STRING : TEXT

# %%
first_name = "William"
last_name = "Sekar"
print(type(first_name))
# Out:
# <class 'str'>

# %%
## INTGER (WHOLE NUMBER)

# %%
age = 29
salary =20000
print(type(age))
# Out:
# <class 'int'>

# %%
## FLOAT (DECIMAL NUMBER)

# %%
height = 5.8
print(type(height))
# Out:
# <class 'float'>

# %%
## BOOLEAN (TRUE/FALSE )

# %%
is_Student = True
is_Logged_in = False
print(type(is_Student))
# Out:
# <class 'bool'>

# %%
# PRINTING VARIABLES TOGETHER

# %%
street_name = "Dharman Street"
pincode = 620001
print(street
