# %%
# ENCAPSULATION
class Bankaccount:
    def __init__(self,balance):
        self.__balance=balance
    def get_balance(self):
        print("Balance: ", self.__balance)
    def deposit(self,amount):
        if amount > 0:     
            self.__balance+=amount  
            print("successfully",amount,"rupee credited to you account ")
    def withdraw(self,amount):
        if amount <= 0:
            print("Invalid amount")
        elif amount > self.__balance:
            print("Insufficient balance")
        else:
            self.__balance-=amount
            print("successfully",amount,"rupee debited from you account ")
            
account=Bankaccount(5000)
account.get_balance()
account.withdraw(0)
account.withdraw(-2)
account.withdraw(10000)
account.withdraw(100)
account.get_balance()
account.deposit(3000)
account.get_balance()
# Out:
# Balance:  5000
# Invalid amount
# Invalid amount
# Insufficient balance
# successfully 100 rupee debited from you account
# Balance:  4900
# successfully 3000 rupee credited to you account
# Balance:  7900
