# %%
 # package
import math_tools
print(math_tools.add(10,17))
print(math_tools.square(2))
print(math_tools.ex(10,4))
print(dir(math_tools))
# Out:
# 27
# 4
# 10000
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'add', 'advanced', 'basic', 'cube', 'div', 'ex', 'floor', 'mod', 'mul', 'square', 'sub']
